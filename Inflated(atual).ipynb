# %% [markdown]
# <a href="https://colab.research.google.com/github/vtponciano-ufrj/Grafos/blob/main/Inflated(atual).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.prefilter import MacroChecker
from networkx.readwrite.json_graph import jit_data
import networkx as nx
from networkx.generators.random_graphs import erdos_renyi_graph
from math import ceil
import networkx as nx
# Not necessary, but will be used later:
import numpy as np 
import matplotlib.pyplot as plt 



def Inflated(H):
  G =  nx.Graph()
  n1=H.number_of_nodes()
  M= nx.Graph()
  
  
  for  i in range(0,n1):
      for  j in range(0,n1):
         if H.has_edge(i,j)==True:
            G.add_node( f'[{str(i)}]'+ f'[{str(i)}'+','+f'{str(j)}]')
  
  
  
  for  i in range(0,n1):
      for  j in range(0,n1):
         if i!=j:
            if G.has_node( f'[{str(i)}]'+ f'[{str(i)}'+','+f'{str(j)}]')==True:
               G.add_edge( f'[{str(i)}]'+ f'[{str(i)}'+','+f'{str(j)}]',f'[{str(j)}]'+ f'[{str(j)}'+','+f'{str(i)}]')



  for  i in range(0,n1):
    for  j in range(0,n1):
       for  k in range(0,n1):
         if G.has_node(f'[{str(i)}]'+ f'[{str(i)}'+','+f'{str(j)}]')==True and  G.has_node(f'[{str(i)}]'+ f'[{str(i)}'+','+f'{str(k)}]')==True:
            if j!=k:
               G.add_edge(f'[{str(i)}]'+ f'[{str(i)}'+','+f'{str(j)}]', f'[{str(i)}]'+ f'[{str(i)}'+','+f'{str(k)}]')

 
  
  nx.write_gexf(G, f"Inflated_cycle{(str(m))}.gexf")
  nx.write_edgelist(G,f"Inflated_cycle{(str(m))}.tgf", delimiter=f" ",data=False)
  nx.write_pajek(G, f"Inflated_cycle{(str(m))}.net")
  nx.draw(G)
  
  


  
  
  
  
  


m=426
H =nx.complete_graph(8)
#H= nx.complete_bipartite_graph(3,4)
#H=nx.circular_ladder_graph(4)
#H=nx.dorogovtsev_goltsev_mendes_graph(4)
#H=nx.lollipop_graph(6,3, create_using=None)
#H=nx.random_regular_graph(4,101, seed=None)
#H=nx.mycielski_graph(4)
Inflated(H)

# %%
H =nx.complete_graph(102)
#H=nx.mycielski_graph(4)
nx.draw(H)
