# %% [markdown]
# <a href="https://colab.research.google.com/github/vtponciano-ufrj/Grafos/blob/main/Inflated_cycle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyyed
import pyyed
import pandas as pd 
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import networkx
import csv
import networkx as nx
from networkx.generators.random_graphs import erdos_renyi_graph


def Inflated(H):
  G =  nx.Graph()
  n= H.number_of_nodes()
  g= pyyed.Graph()
  
  for  i in range(0,n):
      for  j in range(0,n):
         if j!=i:
            if H.has_edge(i,j)==True:
               G.add_edge(str(i)+str(j),str(j)+str(i)) 
  print(G.nodes())
  def circulo(i):
   lista=[]
   for j in range(0,n):
     if i!=j:
      if G.has_node(str(i)+str(j))==True:
          lista.append(str(i)+str(j))
   nx.add_cycle(G,lista)
   del lista[0]       
   #print(lista)
  
  for i in range(0,n):
    circulo(i)
  #print(G.edges())   
  nx.draw(G)
  nx.write_gexf(G, f"Inflated{(str(m))}.gexf")
  nx.write_edgelist(G,f"Inflated{(str(m))}.txt", delimiter=f" ",data=False)
  g.write_graph (f'Inflated{(str(m))}.graphml', pretty_print=True)
  



m=55
#p= 0.10
#H = erdos_renyi_graph(m, p)
H =nx.complete_graph(6)
#H= nx.complete_bipartite_graph(3,4)
#H=nx.circular_ladder_graph(10)
#H=nx.dorogovtsev_goltsev_mendes_graph(4)
#H=nx.lollipop_graph(10,5, create_using=None)
#H=nx.random_regular_graph(4,10, seed=None)
#H=nx.mycielski_graph(4)

Inflated(H)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# ['01', '10', '02', '20', '03', '30', '04', '40', '05', '50', '12', '21', '13', '31', '14', '41', '15', '51', '23', '32', '24', '42', '25', '52', '34', '43', '35', '53', '45', '54']

# %%
lista[0]
# Out:
# '00'

# %%
lista1=[]
for j in range(0,4):
  lista1.append(str(0)+str(j))

del lista1[0]
print(lista1)
# Out:
# ['01', '02', '03']
