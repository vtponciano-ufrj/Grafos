# %% [markdown]
# <a href="https://colab.research.google.com/github/vtponciano-ufrj/Grafos/blob/main/grafos_Networkx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyyed
import pyyed
import pandas as pd 
import matplotlib.pyplot as plt
from networkx.generators.random_graphs import erdos_renyi_graph
import networkx as nx

m=1
#p= 0.10
#H = erdos_renyi_graph(m, p)
#H =nx.complete_graph(100)
#H =nx.cycle_graph(100)
#H =nx.path_graph(100)
#H= nx.complete_bipartite_graph(10,10)
H=nx.circular_ladder_graph(10)
#H=nx.dorogovtsev_goltsev_mendes_graph(10)
#H=nx.lollipop_graph(10,10, create_using=None)
#H=nx.random_cograph(10)
#H=nx.random_regular_graph(3,1200, seed=None)
#H=nx.mycielski_graph(10)
#L = nx.line_graph(H)
nx.write_pajek(H,f"H{(str(m))}.net")
nx.draw(H)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyyed
#   Downloading pyyed-1.5.0.tar.gz (6.2 kB)
# Building wheels for collected packages: pyyed
#   Building wheel for pyyed (setup.py) ... done
#   Created wheel for pyyed: filename=pyyed-1.5.0-py3-none-any.whl size=6718 sha256=2c7c45f5624dfefd084579fb69c788dd5e5f5263054aed0e5d3e34fe6ebbf234
#   Stored in directory: /root/.cache/pip/wheels/14/89/c5/727300856a0b9f5187e8e9a120b24ccde78ee04653d545dec1
# Successfully built pyyed
# Installing collected packages: pyyed
# Successfully installed pyyed-1.5.0
