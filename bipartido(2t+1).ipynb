# %% [markdown]
# <a href="https://colab.research.google.com/github/vtponciano-ufrj/Grafos/blob/main/bipartido(2t%2B1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyyed
import pyyed
import pandas as pd 
import matplotlib.pyplot as plt
from networkx.generators.random_graphs import erdos_renyi_graph
import networkx as nx


def bipartido(H):
  
  G=nx.Graph()
  n= H.number_of_nodes()

  G.add_node('x')
  G.add_node('a')
  G.add_node('b')
  G.add_edge('x','a') 
  G.add_edge('x','b')

  for  i in range(0,n):
      for  j in range(0,n):
         if H.has_edge(i,j)==True:
               if i<j:
                 G.add_node(str(i)+str(j)) 
                 G.add_edge(i,str(i)+str(j))
                 G.add_edge(str(i)+str(j),j)  
                 G.add_edge('x',str(i)+str(j)) 
 
  nx.draw(G)
  nx.write_gexf(G, f"Bipartido{(str(m))}.gexf")
  nx.write_pajek(G,f"Bipartido{(str(m))}.net")

m=54
#p= 0.10
#H = erdos_renyi_graph(m, p)
#H =nx.complete_graph(10)
H =nx.cycle_graph(5)
#H =nx.path_graph(100)
#H= nx.complete_bipartite_graph(5,9)
#H=nx.circular_ladder_graph(300)
#H=nx.dorogovtsev_goltsev_mendes_graph(4)
#H=nx.lollipop_graph(10,5, create_using=None)
#H=nx.random_regular_graph(3,10, seed=None)
#H=nx.mycielski_graph(4)
#H = nx.read_graphml('039.graphml')
#L = nx.line_graph(H)
nx.write_pajek(H,f"Raiz_H{(str(m))}.net")
#nx.draw(H)


bipartido(H)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
